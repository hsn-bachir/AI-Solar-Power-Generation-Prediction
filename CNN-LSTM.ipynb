# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

WINDOW = 24
BATCH_SIZE = 512
EPOCHS = 30
N_SPLITS = 5
MAX_SAMPLES = 400000

data = pd.read_csv("Data/Final_Data.csv")

if "SiteKey" in data.columns:
    data = data.drop(columns=["SiteKey"])

Y_NOW = data["Residual_now"]
Y_TRUE_NOW = data["CapacityFactor"]

Y_MULTI = data[[
    "Residual_15min",
    "Residual_1h",
    "Residual_3h"
]]

Y_TRUE_MULTI = data[[
    "Target_15min",
    "Target_1h",
    "Target_3h"
]]

drop_cols = [
    "CapacityFactor",
    "Target_15min",
    "Target_1h",
    "Target_3h",
    "Residual_15min",
    "Residual_1h",
    "Residual_3h",
    "Residual_now",
    "SolarGeneration"
]
features = data.drop(columns=drop_cols)
features = features.iloc[-MAX_SAMPLES:]

Y_NOW = Y_NOW.iloc[-MAX_SAMPLES:]
Y_TRUE_NOW = Y_TRUE_NOW.iloc[-MAX_SAMPLES:]
Y_MULTI = Y_MULTI.iloc[-MAX_SAMPLES:]
Y_TRUE_MULTI = Y_TRUE_MULTI.iloc[-MAX_SAMPLES:]

lag_now = features["Lag_1"].values.astype(np.float32)
lag_15 = features["Lag_1"].values.astype(np.float32)
lag_1h = features["Lag_2"].values.astype(np.float32)
lag_3h = features["Lag_3"].values.astype(np.float32)

features = features.astype(np.float32)
X_values = features.values.astype(np.float32)
Y_NOW_values = Y_NOW.values.astype(np.float32)
Y_TRUE_NOW_values = Y_TRUE_NOW.values.astype(np.float32)
Y_MULTI_values = Y_MULTI.values.astype(np.float32)
Y_TRUE_MULTI_values = Y_TRUE_MULTI.values.astype(np.float32)

scaler = StandardScaler()
X_values = scaler.fit_transform(X_values)
X_values = X_values.astype(np.float32)

def create_dataset(X, y, start_idx, end_idx):
    dataset = tf.keras.utils.timeseries_dataset_from_array(
        data=X,
        targets=y[WINDOW:end_idx],
        sequence_length=WINDOW,
        sequence_stride=1,
        sampling_rate=1,
        batch_size=BATCH_SIZE,
        start_index=start_idx,
        end_index=end_idx - 1,
        shuffle=False
    )
    return dataset

def build_single_cnn_lstm(num_features):
    model = models.Sequential([
        layers.Input(shape=(WINDOW, num_features)),
        layers.Conv1D(
            filters=64,
            kernel_size=3,
            activation="relu",
            padding="same"
        ),
        layers.Conv1D(
            filters=64,
            kernel_size=3,
            activation="relu",
            padding="same"
        ),
        layers.MaxPooling1D(
            pool_size=2
        ),
        layers.LSTM(
            128,
            return_sequences=True
        ),
        layers.Dropout(0.2),
        layers.LSTM(64),
        layers.Dropout(0.2),
        layers.Dense(
            64,
            activation="relu"
        ),
        layers.Dense(1)
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="mse"
    )
    return model

def build_multi_cnn_lstm(num_features):
    model = models.Sequential([
        layers.Input(shape=(WINDOW, num_features)),
        layers.Conv1D(
            filters=64,
            kernel_size=3,
            activation="relu",
            padding="same"
        ),
        layers.Conv1D(
            filters=64,
            kernel_size=3,
            activation="relu",
            padding="same"
        ),

        layers.MaxPooling1D(
            pool_size=2
        ),
        layers.LSTM(
            128,
            return_sequences=True
        ),
        layers.Dropout(0.2),
        layers.LSTM(64),
        layers.Dropout(0.2),
        layers.Dense(
            64,
            activation="relu"
        ),
        layers.Dense(3)
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss=tf.keras.losses.Huber()
    )
    return model

split_size = len(X_values) // (N_SPLITS + 1)

mae_model_now = 0
mae_naive_now = 0
r2_now = 0
mae_model_multi = np.zeros(3)
mae_naive_multi = np.zeros(3)
r2_multi = np.zeros(3)
horizons = [
    "15 min",
    "1 hour",
    "3 hour"
]

for i in range(N_SPLITS):

    print(f"\n==============================")
    print(f"========== SPLIT {i+1} ==========")
    print(f"==============================")

    train_end = split_size * (i + 1)
    test_end = split_size * (i + 2)

    train_dataset_now = create_dataset(
        X_values,
        Y_NOW_values,
        0,
        train_end
    )

    test_dataset_now = create_dataset(
        X_values,
        Y_NOW_values,
        train_end,
        test_end
    )

    train_dataset_multi = create_dataset(
        X_values,
        Y_MULTI_values,
        0,
        train_end
    )

    test_dataset_multi = create_dataset(
        X_values,
        Y_MULTI_values,
        train_end,
        test_end
    )

    early_stop = callbacks.EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        patience=3,
        factor=0.5,
        verbose=1
    )

    print("\nTRAINING NOW CNN-LSTM MODEL")

    model_now = build_single_cnn_lstm(
        num_features=X_values.shape[1]
    )

    model_now.fit(
        train_dataset_now,
        validation_data=test_dataset_now,
        epochs=EPOCHS,
        callbacks=[
            early_stop,
            reduce_lr
        ],
        verbose=1
    )

    print("\nTRAINING MULTI-HORIZON CNN-LSTM MODEL")
    model_multi = build_multi_cnn_lstm(
        num_features=X_values.shape[1]
    )
    model_multi.fit(
        train_dataset_multi,
        validation_data=test_dataset_multi,
        epochs=EPOCHS,
        callbacks=[
            early_stop,
            reduce_lr
        ],
        verbose=1
    )

    residual_pred_now = model_now.predict(
        test_dataset_now,
        verbose=0
    ).flatten()

    residual_pred_multi = model_multi.predict(
        test_dataset_multi,
        verbose=0
    )

    test_start_real = train_end + WINDOW
    test_end_real = test_end
    true_now = Y_TRUE_NOW_values[
        test_start_real:test_end_real
    ]
    true_multi = Y_TRUE_MULTI_values[
        test_start_real:test_end_real
    ]
    lag_test_now = lag_now[
        test_start_real:test_end_real
    ]
    lag_test_15 = lag_15[
        test_start_real:test_end_real
    ]
    lag_test_1h = lag_1h[
        test_start_real:test_end_real
    ]
    lag_test_3h = lag_3h[
        test_start_real:test_end_real
    ]

    pred_now = lag_test_now + residual_pred_now
    pred_15 = lag_test_15 + residual_pred_multi[:, 0]
    pred_1h = lag_test_1h + residual_pred_multi[:, 1]
    pred_3h = lag_test_3h + residual_pred_multi[:, 2]

    preds_multi = [
        pred_15,
        pred_1h,
        pred_3h
    ]
    lags_multi = [
        lag_test_15,
        lag_test_1h,
        lag_test_3h
    ]

    fold_mae_model_now = mean_absolute_error(
        true_now,
        pred_now
    )

    fold_mae_naive_now = mean_absolute_error(
        true_now,
        lag_test_now
    )

    fold_r2_now = r2_score(
        true_now,
        pred_now
    )

    mae_model_now += fold_mae_model_now
    mae_naive_now += fold_mae_naive_now
    r2_now += fold_r2_now

    for h in range(3):

        fold_mae_model = mean_absolute_error(
            true_multi[:, h],
            preds_multi[h]
        )

        fold_mae_naive = mean_absolute_error(
            true_multi[:, h],
            lags_multi[h]
        )

        fold_r2 = r2_score(
            true_multi[:, h],
            preds_multi[h]
        )

        mae_model_multi[h] += fold_mae_model
        mae_naive_multi[h] += fold_mae_naive
        r2_multi[h] += fold_r2

    print("\n==============================")
    print("NOW PREDICTIONS")
    print("==============================")

    print("Pred :", pred_now[:5])
    print("True :", true_now[:5])
    print("Lag  :", lag_test_now[:5])

    print("\n==============================")
    print("MULTI-HORIZON PREDICTIONS")
    print("==============================")

    print("\n15 MIN")
    print(pred_15[:5])

    print("\n1 HOUR")
    print(pred_1h[:5])

    print("\n3 HOUR")
    print(pred_3h[:5])

mae_model_now /= N_SPLITS
mae_naive_now /= N_SPLITS
r2_now /= N_SPLITS

mae_model_multi /= N_SPLITS
mae_naive_multi /= N_SPLITS
r2_multi /= N_SPLITS

print("\n===================================")
print("FINAL NOW CNN-LSTM RESULTS")
print("===================================")

print("Naive MAE:", mae_naive_now)
print("Model MAE:", mae_model_now)
print("R2:", r2_now)

print("\n===================================")
print("FINAL MULTI-HORIZON CNN-LSTM RESULTS")
print("===================================")

for i, h in enumerate(horizons):

    print(f"\nCNN-LSTM Horizon: {h}")

    print("Naive MAE:", mae_naive_multi[i])

    print("Model MAE:", mae_model_multi[i])

    print("R2:", r2_multi[i])
# Out:
# ==============================
# ========== SPLIT 1 ==========
# ==============================
#
# TRAINING NOW CNN-LSTM MODEL
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 77ms/step - loss: 7.9276e-04 - val_loss: 2.3964e-04 - learning_rate: 0.0010
# Epoch 2/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 2.2746e-04 - val_loss: 2.3472e-04 - learning_rate: 0.0010
# Epoch 3/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 85ms/step - loss: 2.0810e-04 - val_loss: 2.3373e-04 - learning_rate: 0.0010
# Epoch 4/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.1128e-04
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - loss: 2.0095e-04 - val_loss: 2.3156e-04 - learning_rate: 0.0010
# Epoch 5/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - loss: 1.9830e-04 - val_loss: 2.2994e-04 - learning_rate: 5.0000e-04
# Epoch 6/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 1.9731e-04 - val_loss: 2.2893e-04 - learning_rate: 5.0000e-04
# Epoch 7/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.0375e-04
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 1.9453e-04 - val_loss: 2.2748e-04 - learning_rate: 5.0000e-04
# Epoch 8/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - loss: 1.9336e-04 - val_loss: 2.2751e-04 - learning_rate: 2.5000e-04
# Epoch 9/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 1.9251e-04 - val_loss: 2.2744e-04 - learning_rate: 2.5000e-04
# Epoch 10/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.0199e-04
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 1.9284e-04 - val_loss: 2.2682e-04 - learning_rate: 2.5000e-04
# Epoch 11/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - loss: 1.9172e-04 - val_loss: 2.2562e-04 - learning_rate: 1.2500e-04
# Epoch 12/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - loss: 1.9112e-04 - val_loss: 2.2508e-04 - learning_rate: 1.2500e-04
# Epoch 13/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.9929e-04
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 1.9061e-04 - val_loss: 2.2468e-04 - learning_rate: 1.2500e-04
# Epoch 14/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 1.9059e-04 - val_loss: 2.2464e-04 - learning_rate: 6.2500e-05
# Epoch 15/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 1.8990e-04 - val_loss: 2.2452e-04 - learning_rate: 6.2500e-05
# Epoch 16/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.9926e-04
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 1.9045e-04 - val_loss: 2.2434e-04 - learning_rate: 6.2500e-05
# Epoch 17/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - loss: 1.8989e-04 - val_loss: 2.2428e-04 - learning_rate: 3.1250e-05
# Epoch 18/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - loss: 1.8973e-04 - val_loss: 2.2415e-04 - learning_rate: 3.1250e-05
# Epoch 19/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.9783e-04
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - loss: 1.8928e-04 - val_loss: 2.2410e-04 - learning_rate: 3.1250e-05
# Epoch 20/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 1.8909e-04 - val_loss: 2.2400e-04 - learning_rate: 1.5625e-05
# Epoch 21/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - loss: 1.8910e-04 - val_loss: 2.2396e-04 - learning_rate: 1.5625e-05
# Epoch 22/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.9728e-04
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 1.8896e-04 - val_loss: 2.2389e-04 - learning_rate: 1.5625e-05
# Epoch 23/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 1.8890e-04 - val_loss: 2.2379e-04 - learning_rate: 7.8125e-06
# Epoch 24/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - loss: 1.8909e-04 - val_loss: 2.2375e-04 - learning_rate: 7.8125e-06
# Epoch 25/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.9714e-04
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - loss: 1.8899e-04 - val_loss: 2.2372e-04 - learning_rate: 7.8125e-06
# Epoch 26/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 1.8855e-04 - val_loss: 2.2368e-04 - learning_rate: 3.9063e-06
# Epoch 27/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - loss: 1.8906e-04 - val_loss: 2.2366e-04 - learning_rate: 3.9063e-06
# Epoch 28/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.9711e-04
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 1.8861e-04 - val_loss: 2.2363e-04 - learning_rate: 3.9063e-06
# Epoch 29/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - loss: 1.8858e-04 - val_loss: 2.2362e-04 - learning_rate: 1.9531e-06
# Epoch 30/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 91ms/step - loss: 1.8875e-04 - val_loss: 2.2361e-04 - learning_rate: 1.9531e-06
#
# TRAINING MULTI-HORIZON CNN-LSTM MODEL
# Epoch 1/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - loss: 5.9613e-04 - val_loss: 4.7815e-04 - learning_rate: 0.0010
# Epoch 2/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 87ms/step - loss: 3.3623e-04 - val_loss: 5.3699e-04 - learning_rate: 0.0010
# Epoch 3/30
# 130/131 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.3581e-04
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - loss: 2.9874e-04 - val_loss: 3.9582e-04 - learning_rate: 0.0010
# Epoch 4/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - loss: 2.8047e-04 - val_loss: 3.7620e-04 - learning_rate: 5.0000e-04
# Epoch 5/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 91ms/step - loss: 2.7308e-04 - val_loss: 3.5242e-04 - learning_rate: 5.0000e-04
#
# ==============================
# NOW PREDICTIONS
# ==============================
# Pred : [0.03349646 0.04308676 0.05628843 0.0710119  0.0908602 ]
# True : [0.03488434 0.04801571 0.06220819 0.08250212 0.09404181]
# Lag  : [0.02705857 0.03488434 0.04801571 0.06220819 0.08250212]
#
# ==============================
# MULTI-HORIZON PREDICTIONS
# ==============================
#
# 15 MIN
# [0.04322355 0.0519202  0.06663681 0.0794695  0.10042579]
#
# 1 HOUR
# [0.05348722 0.06322461 0.07111737 0.0846864  0.09797632]
#
# 3 HOUR
# [0.08820884 0.09162838 0.09965203 0.10201035 0.10908286]
#
# ==============================
# ========== SPLIT 2 ==========
# ==============================
#
# TRAINING NOW CNN-LSTM MODEL
# Epoch 1/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 7.1872e-04 - val_loss: 2.2809e-04 - learning_rate: 0.0010
# Epoch 2/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - loss: 2.3172e-04 - val_loss: 2.1926e-04 - learning_rate: 0.0010
# Epoch 3/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - loss: 2.1806e-04 - val_loss: 2.1832e-04 - learning_rate: 0.0010
# Epoch 4/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.0644e-04
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 53ms/step - loss: 2.1058e-04 - val_loss: 2.1446e-04 - learning_rate: 0.0010
# Epoch 5/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 14s 53ms/step - loss: 2.0562e-04 - val_loss: 2.1036e-04 - learning_rate: 5.0000e-04
# Epoch 6/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - loss: 2.0339e-04 - val_loss: 2.1033e-04 - learning_rate: 5.0000e-04
# Epoch 7/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.9566e-04
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - loss: 2.0145e-04 - val_loss: 2.0730e-04 - learning_rate: 5.0000e-04
# Epoch 8/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 20s 76ms/step - loss: 2.0109e-04 - val_loss: 2.0330e-04 - learning_rate: 2.5000e-04
# Epoch 9/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 21s 80ms/step - loss: 1.9970e-04 - val_loss: 2.0159e-04 - learning_rate: 2.5000e-04
# Epoch 10/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.9320e-04
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - loss: 1.9902e-04 - val_loss: 2.0071e-04 - learning_rate: 2.5000e-04
# Epoch 11/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - loss: 1.9897e-04 - val_loss: 2.0127e-04 - learning_rate: 1.2500e-04
# Epoch 12/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - loss: 1.9860e-04 - val_loss: 2.0155e-04 - learning_rate: 1.2500e-04
# Epoch 13/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.9208e-04
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - loss: 1.9788e-04 - val_loss: 2.0066e-04 - learning_rate: 1.2500e-04
# Epoch 14/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9769e-04 - val_loss: 1.9909e-04 - learning_rate: 6.2500e-05
# Epoch 15/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - loss: 1.9689e-04 - val_loss: 1.9827e-04 - learning_rate: 6.2500e-05
# Epoch 16/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.9029e-04
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9687e-04 - val_loss: 1.9764e-04 - learning_rate: 6.2500e-05
# Epoch 17/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 71ms/step - loss: 1.9617e-04 - val_loss: 1.9753e-04 - learning_rate: 3.1250e-05
# Epoch 18/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - loss: 1.9601e-04 - val_loss: 1.9729e-04 - learning_rate: 3.1250e-05
# Epoch 19/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.8961e-04
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - loss: 1.9603e-04 - val_loss: 1.9716e-04 - learning_rate: 3.1250e-05
# Epoch 20/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - loss: 1.9555e-04 - val_loss: 1.9706e-04 - learning_rate: 1.5625e-05
# Epoch 21/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 71ms/step - loss: 1.9534e-04 - val_loss: 1.9695e-04 - learning_rate: 1.5625e-05
# Epoch 22/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.8883e-04
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9551e-04 - val_loss: 1.9684e-04 - learning_rate: 1.5625e-05
# Epoch 23/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - loss: 1.9552e-04 - val_loss: 1.9683e-04 - learning_rate: 7.8125e-06
# Epoch 24/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9526e-04 - val_loss: 1.9682e-04 - learning_rate: 7.8125e-06
# Epoch 25/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.8831e-04
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9506e-04 - val_loss: 1.9676e-04 - learning_rate: 7.8125e-06
# Epoch 26/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9543e-04 - val_loss: 1.9671e-04 - learning_rate: 3.9063e-06
# Epoch 27/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - loss: 1.9509e-04 - val_loss: 1.9671e-04 - learning_rate: 3.9063e-06
# Epoch 28/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.8852e-04
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9508e-04 - val_loss: 1.9668e-04 - learning_rate: 3.9063e-06
# Epoch 29/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 18s 70ms/step - loss: 1.9522e-04 - val_loss: 1.9666e-04 - learning_rate: 1.9531e-06
# Epoch 30/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - loss: 1.9514e-04 - val_loss: 1.9666e-04 - learning_rate: 1.9531e-06
#
# TRAINING MULTI-HORIZON CNN-LSTM MODEL
# Epoch 1/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - loss: 4.5794e-04 - val_loss: 7.0403e-04 - learning_rate: 0.0010
# Epoch 2/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - loss: 3.0777e-04 - val_loss: 5.1872e-04 - learning_rate: 0.0010
# Epoch 3/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2.9177e-04
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 75ms/step - loss: 2.8703e-04 - val_loss: 4.4331e-04 - learning_rate: 0.0010
# Epoch 4/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - loss: 2.7497e-04 - val_loss: 3.2942e-04 - learning_rate: 5.0000e-04
# Epoch 5/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - loss: 2.6113e-04 - val_loss: 3.1026e-04 - learning_rate: 5.0000e-04
#
# ==============================
# NOW PREDICTIONS
# ==============================
# Pred : [0.10854108 0.08159402 0.0542207  0.07537173 0.15586731]
# True : [0.09579445 0.05675547 0.0666328  0.14816    0.11586268]
# Lag  : [0.13436309 0.09579445 0.05675547 0.0666328  0.14816   ]
#
# ==============================
# MULTI-HORIZON PREDICTIONS
# ==============================
#
# 15 MIN
# [0.125388   0.08791784 0.04881274 0.05916731 0.14041403]
#
# 1 HOUR
# [0.07588124 0.10490607 0.06371658 0.02520587 0.03349029]
#
# 3 HOUR
# [-0.05136796  0.03589111  0.05774218  0.02452733 -0.01450888]
#
# ==============================
# ========== SPLIT 3 ==========
# ==============================
#
# TRAINING NOW CNN-LSTM MODEL
# Epoch 1/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 73ms/step - loss: 6.6245e-04 - val_loss: 2.2265e-04 - learning_rate: 0.0010
# Epoch 2/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 2.2323e-04 - val_loss: 2.1754e-04 - learning_rate: 0.0010
# Epoch 3/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 2.1521e-04 - val_loss: 2.1719e-04 - learning_rate: 0.0010
# Epoch 4/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2.0581e-04
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 2.0813e-04 - val_loss: 2.1137e-04 - learning_rate: 0.0010
# Epoch 5/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - loss: 2.0400e-04 - val_loss: 2.0709e-04 - learning_rate: 5.0000e-04
# Epoch 6/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 2.0185e-04 - val_loss: 2.0563e-04 - learning_rate: 5.0000e-04
# Epoch 7/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.9699e-04
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 2.0046e-04 - val_loss: 2.0500e-04 - learning_rate: 5.0000e-04
# Epoch 8/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - loss: 1.9940e-04 - val_loss: 2.0297e-04 - learning_rate: 2.5000e-04
# Epoch 9/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - loss: 1.9916e-04 - val_loss: 2.0126e-04 - learning_rate: 2.5000e-04
# Epoch 10/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.9406e-04
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9818e-04 - val_loss: 2.0032e-04 - learning_rate: 2.5000e-04
# Epoch 11/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9716e-04 - val_loss: 1.9951e-04 - learning_rate: 1.2500e-04
# Epoch 12/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9679e-04 - val_loss: 1.9896e-04 - learning_rate: 1.2500e-04
# Epoch 13/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.9178e-04
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9604e-04 - val_loss: 1.9856e-04 - learning_rate: 1.2500e-04
# Epoch 14/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9532e-04 - val_loss: 1.9826e-04 - learning_rate: 6.2500e-05
# Epoch 15/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9491e-04 - val_loss: 1.9775e-04 - learning_rate: 6.2500e-05
# Epoch 16/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.9008e-04
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9449e-04 - val_loss: 1.9758e-04 - learning_rate: 6.2500e-05
# Epoch 17/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9436e-04 - val_loss: 1.9719e-04 - learning_rate: 3.1250e-05
# Epoch 18/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9424e-04 - val_loss: 1.9704e-04 - learning_rate: 3.1250e-05
# Epoch 19/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.8961e-04
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9403e-04 - val_loss: 1.9685e-04 - learning_rate: 3.1250e-05
# Epoch 20/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 1.9326e-04 - val_loss: 1.9661e-04 - learning_rate: 1.5625e-05
# Epoch 21/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9345e-04 - val_loss: 1.9648e-04 - learning_rate: 1.5625e-05
# Epoch 22/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.8912e-04
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9351e-04 - val_loss: 1.9633e-04 - learning_rate: 1.5625e-05
# Epoch 23/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9332e-04 - val_loss: 1.9620e-04 - learning_rate: 7.8125e-06
# Epoch 24/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 1.9327e-04 - val_loss: 1.9617e-04 - learning_rate: 7.8125e-06
# Epoch 25/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.8885e-04
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - loss: 1.9302e-04 - val_loss: 1.9606e-04 - learning_rate: 7.8125e-06
# Epoch 26/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 1.9305e-04 - val_loss: 1.9596e-04 - learning_rate: 3.9063e-06
# Epoch 27/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - loss: 1.9286e-04 - val_loss: 1.9592e-04 - learning_rate: 3.9063e-06
# Epoch 28/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.8841e-04
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - loss: 1.9283e-04 - val_loss: 1.9586e-04 - learning_rate: 3.9063e-06
# Epoch 29/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9269e-04 - val_loss: 1.9582e-04 - learning_rate: 1.9531e-06
# Epoch 30/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - loss: 1.9269e-04 - val_loss: 1.9581e-04 - learning_rate: 1.9531e-06
#
# TRAINING MULTI-HORIZON CNN-LSTM MODEL
# Epoch 1/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 74ms/step - loss: 4.8215e-04 - val_loss: 3.8351e-04 - learning_rate: 0.0010
# Epoch 2/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 2.8382e-04 - val_loss: 2.8357e-04 - learning_rate: 0.0010
# Epoch 3/30
# 390/391 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.6921e-04
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 2.6116e-04 - val_loss: 2.7849e-04 - learning_rate: 0.0010
# Epoch 4/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 2.4946e-04 - val_loss: 3.1058e-04 - learning_rate: 5.0000e-04
# Epoch 5/30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 2.4440e-04 - val_loss: 2.5938e-04 - learning_rate: 5.0000e-04
#
# ==============================
# NOW PREDICTIONS
# ==============================
# Pred : [0.00073293 0.00802385 0.01444922 0.0261244  0.0359451 ]
# True : [0.00748412 0.0135936  0.02092498 0.02963099 0.04016984]
# Lag  : [0.00397116 0.00748412 0.0135936  0.02092498 0.02963099]
#
# ==============================
# MULTI-HORIZON PREDICTIONS
# ==============================
#
# 15 MIN
# [0.00984255 0.01490528 0.02241206 0.03123454 0.0429506 ]
#
# 1 HOUR
# [0.01606457 0.01818494 0.0265454  0.03564356 0.04921937]
#
# 3 HOUR
# [0.06724533 0.0740644  0.07748856 0.08452267 0.09463406]
#
# ==============================
# ========== SPLIT 4 ==========
# ==============================
#
# TRAINING NOW CNN-LSTM MODEL
# Epoch 1/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 40s 69ms/step - loss: 3.7474e-04 - val_loss: 1.4011e-04 - learning_rate: 0.0010
# Epoch 2/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 2.1701e-04 - val_loss: 1.3591e-04 - learning_rate: 0.0010
# Epoch 3/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 2.1053e-04 - val_loss: 1.3325e-04 - learning_rate: 0.0010
# Epoch 4/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 2.0113e-04
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 2.0381e-04 - val_loss: 1.3166e-04 - learning_rate: 0.0010
# Epoch 5/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 2.0089e-04 - val_loss: 1.3049e-04 - learning_rate: 5.0000e-04
# Epoch 6/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 1.9929e-04 - val_loss: 1.2961e-04 - learning_rate: 5.0000e-04
# Epoch 7/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.9416e-04
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 70ms/step - loss: 1.9784e-04 - val_loss: 1.2945e-04 - learning_rate: 5.0000e-04
# Epoch 8/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 1.9589e-04 - val_loss: 1.2818e-04 - learning_rate: 2.5000e-04
# Epoch 9/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 70ms/step - loss: 1.9489e-04 - val_loss: 1.2910e-04 - learning_rate: 2.5000e-04
# Epoch 10/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.9015e-04
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 1.9376e-04 - val_loss: 1.2672e-04 - learning_rate: 2.5000e-04
# Epoch 11/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 1.9230e-04 - val_loss: 1.2585e-04 - learning_rate: 1.2500e-04
# Epoch 12/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 1.9117e-04 - val_loss: 1.2553e-04 - learning_rate: 1.2500e-04
# Epoch 13/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.8724e-04
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 70ms/step - loss: 1.9036e-04 - val_loss: 1.2482e-04 - learning_rate: 1.2500e-04
# Epoch 14/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 70ms/step - loss: 1.8917e-04 - val_loss: 1.2652e-04 - learning_rate: 6.2500e-05
# Epoch 15/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 36s 70ms/step - loss: 1.8828e-04 - val_loss: 1.2627e-04 - learning_rate: 6.2500e-05
# Epoch 16/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.8415e-04
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 34s 65ms/step - loss: 1.8730e-04 - val_loss: 1.2523e-04 - learning_rate: 6.2500e-05
# Epoch 17/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 1.8659e-04 - val_loss: 1.2482e-04 - learning_rate: 3.1250e-05
# Epoch 18/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 1.8588e-04 - val_loss: 1.2487e-04 - learning_rate: 3.1250e-05
# Epoch 19/30
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.8256e-04
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - loss: 1.8560e-04 - val_loss: 1.2373e-04 - learning_rate: 3.1250e-05
# Epoch 20/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 1.8474e-04 - val_loss: 1.2347e-04 - learning_rate: 1.5625e-05
# Epoch 21/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - loss: 1.8473e-04 - val_loss: 1.2370e-04 - learning_rate: 1.5625e-05
# Epoch 22/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.8110e-04
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 1.8429e-04 - val_loss: 1.2404e-04 - learning_rate: 1.5625e-05
# Epoch 23/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 1.8393e-04 - val_loss: 1.2377e-04 - learning_rate: 7.8125e-06
# Epoch 24/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 1.8365e-04 - val_loss: 1.2411e-04 - learning_rate: 7.8125e-06
# Epoch 25/30
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.8076e-04
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 1.8388e-04 - val_loss: 1.2389e-04 - learning_rate: 7.8125e-06
#
# TRAINING MULTI-HORIZON CNN-LSTM MODEL
# Epoch 1/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 29s 51ms/step - loss: 4.0767e-04 - val_loss: 3.1619e-04 - learning_rate: 0.0010
# Epoch 2/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 52ms/step - loss: 2.7638e-04 - val_loss: 2.1911e-04 - learning_rate: 0.0010
# Epoch 3/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.5559e-04
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 2.5266e-04 - val_loss: 1.9508e-04 - learning_rate: 0.0010
# Epoch 4/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 2.4422e-04 - val_loss: 1.7607e-04 - learning_rate: 5.0000e-04
# Epoch 5/30
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 2.4068e-04 - val_loss: 1.7753e-04 - learning_rate: 5.0000e-04
#
# ==============================
# NOW PREDICTIONS
# ==============================
# Pred : [0.18040808 0.12724906 0.05975406 0.13288319 0.06796496]
# True : [0.14562412 0.0759778  0.1253909  0.07570252 0.08341041]
# Lag  : [0.19476193 0.14562412 0.0759778  0.1253909  0.07570252]
#
# ==============================
# MULTI-HORIZON PREDICTIONS
# ==============================
#
# 15 MIN
# [0.2012116  0.14354399 0.0754709  0.12455367 0.07261259]
#
# 1 HOUR
# [0.15617083 0.17124298 0.12730171 0.05534991 0.10156697]
#
# 3 HOUR
# [0.04754208 0.07149205 0.12097842 0.07924156 0.00459348]
#
# ==============================
# ========== SPLIT 5 ==========
# ==============================
#
# TRAINING NOW CNN-LSTM MODEL
# Epoch 1/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 38s 54ms/step - loss: 3.4834e-04 - val_loss: 1.7058e-04 - learning_rate: 0.0010
# Epoch 2/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 37s 57ms/step - loss: 1.9805e-04 - val_loss: 1.6808e-04 - learning_rate: 0.0010
# Epoch 3/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 35s 54ms/step - loss: 1.9011e-04 - val_loss: 1.6312e-04 - learning_rate: 0.0010
# Epoch 4/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.9624e-04
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 38s 58ms/step - loss: 1.8517e-04 - val_loss: 1.6046e-04 - learning_rate: 0.0010
# Epoch 5/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 37s 56ms/step - loss: 1.8202e-04 - val_loss: 1.5743e-04 - learning_rate: 5.0000e-04
# Epoch 6/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 35s 54ms/step - loss: 1.8041e-04 - val_loss: 1.5645e-04 - learning_rate: 5.0000e-04
# Epoch 7/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.8909e-04
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 55ms/step - loss: 1.7893e-04 - val_loss: 1.5394e-04 - learning_rate: 5.0000e-04
# Epoch 8/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 56ms/step - loss: 1.7676e-04 - val_loss: 1.5326e-04 - learning_rate: 2.5000e-04
# Epoch 9/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 55ms/step - loss: 1.7518e-04 - val_loss: 1.5207e-04 - learning_rate: 2.5000e-04
# Epoch 10/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.8394e-04
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 55ms/step - loss: 1.7357e-04 - val_loss: 1.5224e-04 - learning_rate: 2.5000e-04
# Epoch 11/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 35s 53ms/step - loss: 1.7211e-04 - val_loss: 1.5174e-04 - learning_rate: 1.2500e-04
# Epoch 12/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 56ms/step - loss: 1.7048e-04 - val_loss: 1.5051e-04 - learning_rate: 1.2500e-04
# Epoch 13/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.7955e-04
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 55ms/step - loss: 1.6893e-04 - val_loss: 1.4949e-04 - learning_rate: 1.2500e-04
# Epoch 14/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 38s 58ms/step - loss: 1.6690e-04 - val_loss: 1.4735e-04 - learning_rate: 6.2500e-05
# Epoch 15/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 55ms/step - loss: 1.6513e-04 - val_loss: 1.4632e-04 - learning_rate: 6.2500e-05
# Epoch 16/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.7466e-04
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 56ms/step - loss: 1.6419e-04 - val_loss: 1.4657e-04 - learning_rate: 6.2500e-05
# Epoch 17/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 36s 55ms/step - loss: 1.6328e-04 - val_loss: 1.4596e-04 - learning_rate: 3.1250e-05
# Epoch 18/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 35s 54ms/step - loss: 1.6262e-04 - val_loss: 1.4606e-04 - learning_rate: 3.1250e-05
# Epoch 19/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.7199e-04
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 37s 57ms/step - loss: 1.6170e-04 - val_loss: 1.4549e-04 - learning_rate: 3.1250e-05
# Epoch 20/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 37s 56ms/step - loss: 1.6119e-04 - val_loss: 1.4477e-04 - learning_rate: 1.5625e-05
# Epoch 21/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 37s 56ms/step - loss: 1.6065e-04 - val_loss: 1.4473e-04 - learning_rate: 1.5625e-05
# Epoch 22/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.7096e-04
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 38s 58ms/step - loss: 1.6037e-04 - val_loss: 1.4435e-04 - learning_rate: 1.5625e-05
# Epoch 23/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 39s 60ms/step - loss: 1.6022e-04 - val_loss: 1.4423e-04 - learning_rate: 7.8125e-06
# Epoch 24/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 45s 69ms/step - loss: 1.5976e-04 - val_loss: 1.4395e-04 - learning_rate: 7.8125e-06
# Epoch 25/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.7039e-04
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 45s 69ms/step - loss: 1.5975e-04 - val_loss: 1.4375e-04 - learning_rate: 7.8125e-06
# Epoch 26/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 44s 68ms/step - loss: 1.5992e-04 - val_loss: 1.4291e-04 - learning_rate: 3.9063e-06
# Epoch 27/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 44s 68ms/step - loss: 1.5949e-04 - val_loss: 1.4294e-04 - learning_rate: 3.9063e-06
# Epoch 28/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.7012e-04
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 39s 60ms/step - loss: 1.5955e-04 - val_loss: 1.4272e-04 - learning_rate: 3.9063e-06
# Epoch 29/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 43s 67ms/step - loss: 1.6003e-04 - val_loss: 1.4156e-04 - learning_rate: 1.9531e-06
# Epoch 30/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 44s 67ms/step - loss: 1.5963e-04 - val_loss: 1.4146e-04 - learning_rate: 1.9531e-06
#
# TRAINING MULTI-HORIZON CNN-LSTM MODEL
# Epoch 1/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 49s 68ms/step - loss: 3.3445e-04 - val_loss: 2.8087e-04 - learning_rate: 0.0010
# Epoch 2/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 44s 68ms/step - loss: 2.4205e-04 - val_loss: 2.2889e-04 - learning_rate: 0.0010
# Epoch 3/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 2.4418e-04
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 44s 68ms/step - loss: 2.2400e-04 - val_loss: 2.1850e-04 - learning_rate: 0.0010
# Epoch 4/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 45s 68ms/step - loss: 2.1545e-04 - val_loss: 2.4093e-04 - learning_rate: 5.0000e-04
# Epoch 5/30
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 45s 68ms/step - loss: 2.0884e-04 - val_loss: 2.5206e-04 - learning_rate: 5.0000e-04
#
# ==============================
# NOW PREDICTIONS
# ==============================
# Pred : [-9.5857089e-05 -1.8014752e-04 -1.1390075e-04 -1.4926007e-04
#  -1.5461929e-04]
# True : [0. 0. 0. 0. 0.]
# Lag  : [0. 0. 0. 0. 0.]
#
# ==============================
# MULTI-HORIZON PREDICTIONS
# ==============================
#
# 15 MIN
# [-0.00125909 -0.00095211 -0.0005706  -0.0005706  -0.0005706 ]
#
# 1 HOUR
# [ 0.03016595 -0.00022416 -0.00014934 -0.00014934 -0.00014934]
#
# 3 HOUR
# [ 0.03401528  0.03007312 -0.00042089 -0.00042089 -0.00042089]
#
# ===================================
# FINAL NOW CNN-LSTM RESULTS
# ===================================
# Naive MAE: 0.006536885630339384
# Model MAE: 0.005943501181900501
# R2: 0.9325403213500977
#
# ===================================
# FINAL MULTI-HORIZON CNN-LSTM RESULTS
# ===================================
#
# CNN-LSTM Horizon: 15 min
# Naive MAE: 0.009727915562689305
# Model MAE: 0.009951521642506123
# R2: 0.8671794533729553
#
# CNN-LSTM Horizon: 1 hour
# Naive MAE: 0.018569910153746604
# Model MAE: 0.016296820156276225
# R2: 0.7155422329902649
#
# CNN-LSTM Horizon: 3 hour
# Naive MAE: 0.03533318601548672
# Model MAE: 0.025263978540897368
# R2: 0.3531124949455261
